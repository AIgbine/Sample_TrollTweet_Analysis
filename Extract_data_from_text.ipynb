# %% [markdown]
# <a href="https://colab.research.google.com/github/AIgbine/Sample_TrollTweet_Analysis/blob/main/Extract_data_from_text.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import textract
text = textract.process("AllProgressivesSupporters.docx")

# %%
text[:500]
# Out:
# b'f \n\nAll Progressives Supporters \n\nKanishk \n\nHome \n\nCreate \n\n: \n\n4 \n\n@ \n\nPC \n\nAll Progressives Supporters @allprogng \n\nAPC \n\nHome \n\nPosts \n\nLike \n\nFollow \n\nShare \n\nSend Message \n\nReviews \n\nCreate Post \n\nVideos \n\nCommunity \n\nPhotos \n\nO \n\n, \n\nWrite a post... \n\nCommunity \n\nSee All \n\nAbout \n\nCommunity \n\nPhoto/Video \n\nTag Friends \n\nCheck in \n\n.. \n\nInvite your friends to like this Page \n\n6,660 people like this \n\n6,751 people follow this \n\nCreate a Page \n\nPosts \n\nAbout \n\nSee All \n\nSend Message Community'

# %%
d = text.decode('utf-8')

# %%
d[:500]
# Out:
# 'f \n\nAll Progressives Supporters \n\nKanishk \n\nHome \n\nCreate \n\n: \n\n4 \n\n@ \n\nPC \n\nAll Progressives Supporters @allprogng \n\nAPC \n\nHome \n\nPosts \n\nLike \n\nFollow \n\nShare \n\nSend Message \n\nReviews \n\nCreate Post \n\nVideos \n\nCommunity \n\nPhotos \n\nO \n\n, \n\nWrite a post... \n\nCommunity \n\nSee All \n\nAbout \n\nCommunity \n\nPhoto/Video \n\nTag Friends \n\nCheck in \n\n.. \n\nInvite your friends to like this Page \n\n6,660 people like this \n\n6,751 people follow this \n\nCreate a Page \n\nPosts \n\nAbout \n\nSee All \n\nSend Message Community'

# %%
type(d)
# Out:
# str

# %%
#Clean text
import re
#import string.punctuation

'''Make text lowercase, remove text in square brackets, remove punctuation and remove words containing numbers.'''
def clean_text(text):
    text = text.lower()
    text = str(text)
    text = re.sub('\[.*?\@#]', '', text)
    text = re.sub('\w*\d\w*', '', text)
    text = re.sub('[‘’“”…]', '', text)
    text = re.sub('\n', '', text)
    return(text[:500])

# %%
clean_text(d)
# Out:
# 'f all progressives supporters kanishk home create :  @ pc all progressives supporters @allprogng apc home posts like follow share send message reviews create post videos community photos o , write a post... community see all about community photo/video tag friends check in .. invite your friends to like this page , people like this , people follow this create a page posts about see all send message community  all progressives supporters february . my heartfelt sympathy goes out to the families o'

# %%
# Install and import libraries
#!pip install gensim
import nltk
from nltk.corpus import stopwords
from nltk.stem.wordnet import WordNetLemmatizer

import string
# Further Text preprocessing
exclude = ['like','comments','comment','reply','w','shares','share','k','view']
stopwords = nltk.corpus.stopwords.words('english')
stopwords.extend(exclude)

lemma = WordNetLemmatizer()
text = ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)"," ",d).lower().split())
texts = ''.join([i for i in text if not i.isdigit()])
texts = " ".join([i for i in texts.lower().split() if i not in stopwords])
texts
# Out:
# 'f progressives supporters kanishk home create pc progressives supporters apc home posts follow send message reviews create post videos community photos write post community see community photo video tag friends check invite friends page people people follow create page posts see send message community progressives supporters february heartfelt sympathy goes families fallen heroes apc attended rally ph words describe numbness felt heart learnt demise pray god comfort families friends party members may souls rip amen suggest edits f page transparency see facebook showing information help better understand purpose page see actions taken people manage post content page created july pages visible yaar aap ek kam kro lodhi col neverheardmusic ii infolego related pages progressives supporters february tonye cole welcome president rivers state wegodoam riversdecides nala naija h news media website omo agege suppor public figure nigeria wants buhari community service english us urretyl welco
# ...

# %%
from collections import Counter
words = Counter([t for t in texts.split()])
words
# Out:
# Counter({'f': 2,
#          'progressives': 28,
#          'supporters': 26,
#          'kanishk': 1,
#          'home': 2,
#          'create': 3,
#          'pc': 6,
#          'apc': 16,
#          'posts': 3,
#          'follow': 2,
#          'send': 8,
#          'message': 8,
#          'reviews': 2,
#          'post': 3,
#          'videos': 2,
#          'community': 11,
#          'photos': 2,
#          'write': 15,
#          'see': 20,
#          'photo': 1,
#          'video': 1,
#          'tag': 1,
#          'friends': 3,
#          'check': 1,
#          'invite': 1,
#          'page': 6,
#          'people': 9,
#          'february': 8,
#          'heartfelt': 1,
#          'sympathy': 1,
#          'goes': 1,
#          'families': 2,
#          'fallen': 1,
#          'heroes': 1,
#          'attended': 1,
#          'rally': 1,
#          'ph': 1,
#          'words': 1,
#          'describe': 1,
#          'numbness': 1,
#          'felt': 1,
# ...

# %%
sort_words = sorted(words.items(), key=lambda x: x[1], reverse=True)
sort_words[:30]
# Out:
# [('progressives', 28),
#  ('supporters', 26),
#  ('see', 20),
#  ('apc', 16),
#  ('write', 15),
#  ('relevant', 14),
#  ('pdp', 12),
#  ('community', 11),
#  ('rivers', 11),
#  ('nigeria', 10),
#  ('people', 9),
#  ('state', 9),
#  ('december', 9),
#  ('send', 8),
#  ('message', 8),
#  ('february', 8),
#  ('years', 8),
#  ('let', 7),
#  ('pc', 6),
#  ('page', 6),
#  ('god', 6),
#  ('tonye', 6),
#  ('cole', 6),
#  ('kill', 6),
#  ('charge', 5),
#  ('hope', 5),
#  ('dey', 5),
#  ('od', 5),
#  ('vote', 5),
#  ('party', 4)]

# %%
from wordcloud import WordCloud,ImageColorGenerator
import matplotlib.pyplot as plt
#WordCloud after some data cleaning
text = ' '.join([str(x) for x in texts.split()])

wc = WordCloud(background_color='white',max_words=200,scale=3).generate(text)
plt.figure(figsize=(15,15))
plt.axis('off')
plt.imshow(wc)
plt.show()
